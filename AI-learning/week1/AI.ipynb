# %%
#1.	인공지능에서 지능에 해당하는 기능은 무엇인가?
#학습, 해결, 인식, 추론, 자연어 처리

#2.	인공지능의 종류 3가지에 대해서 설명하시오 (지도학습, 반지도학습, 강화학습)
#지도학습-주어진 입력 데이터와 대응하는 정답이 있고 반지도 학습은 정답이 없다. 강화학습은 환경과 상호작용하면서 최적의 행동을 찾아내는 것

#3.	전통적인 프로그래밍 방법과 인공지능 프로그램의 차이점은 무엇인가?
#입력->규칙(프로그래머)->출력(정답)
#ai-입력, 출력(정답)->규칙(API)->새로운 데이터에 입력

#4.	딥러닝과 머신러닝의 차이점은 무엇인가?
#머신-특징을 추출 후 분류
#딥-모델 안에서 분류

#5.	Classification과 Regression의 주된 차이점은?
#출력값의 유형
#분류는 범주형(범주나 클래스), 회귀는 연속형(연속적인 숫자값)

#6.	머신러닝에서 차원의 저주(curse of dimensionality)란?
#데이터의 특성(차원)이 증가함에 따라 문제가 발생하는 현상
#주로 고차원 데이터에서 발생-> 데이터 희소성, KNN같은 거리 기반 알고리즘 성능 저하 등

#7.	Dimensionality Reduction는 왜 필요한가?
#차원의 저주 해결, 과적합 방지, 시각화 용이, 노이즈 제거

#8.	Ridge와 Lasso의 공통점과 차이점? (Regularization, 규제 , Scaling)
#공통점- 회귀 모델의 복잡도 제어, 가중치에 제약을 둠, 과적합 방지를 위해 정규화를 사용, 데이터의 스케일에 민감(특성 스케일링 필요)

#차이점
#Ridge Regression- L2정규화(가중치 벡터의 제곱합에 비례), 가중치를 0으로 X 모든 특성을 유지하며 작게 만든다, 조합 해석 용이
#Lasso Regression- L1정규화(가중치 벡터의 절댓값 합에 비례), 일부 가중치를 0으로 O 특성 선택 가능, 중요도 파악 용이

#9.	Overfitting vs. Underfitting
#모델이 학습이 너무 많이 되어서 발생하는 현상- 아웃리어도 모두 학습해서 노이즈가 포함되어 값이 튐.
#	해결책 정규화, 모델 단순화, 규제(데이터를 단순하게)-L1, L2
#Under fitting(과소적합)- 모델이 학습이 충분히 되지 않아서 발생하는 현상- 데이터가 부족, 모델이 단순해서 발생
#-> 해결책 1. 데이터 증대 2. 좀 더 복잡한 모델 사용

#10.Feature Engineering과 Feature Selection의 차이점은?
#Feature Engineering- 새로운 feature를 생성, 기존 feature를 변환하여 모델의 성능 개선

#feature selection- 상관관계도 및 중요도를 따져서 필수적인 feature만 사용하면 정확도가 올라감

#10.	전처리(Preprocessing)의 목적과 방법? (노이즈, 이상치, 결측치)
#데이터 품질 향상, 모델의 성능 최적화
#방법-> 노이즈 필터링, 이상치 탐지, 제거, 클리핑(일정 범위 내로 잘라냄), 결측치를 제거하거나 대체

#11.	EDA(Explorary Data Analysis)란? 데이터의 특성 파악(분포, 상관관계)
#탐색적 데이터 분석=데이터를 시각적으로 분석, 데이터를 탐색하여 패턴, 특성, 관계를 이해하는 과정
#특성, 분포, 이상치를 파악, 변수 간의 상관관계 분석

#12.	회귀에서 절편과 기울기가 의미하는 바는? 딥러닝과 어떻게 연관되는가?
#-절편은 회귀 직선이 y축과 만나는 지점 즉, 독립변수(x)가 0일 때, 종속 변수(y)으 값
#-기울기는 독립 변수(입력 변수)와 종속 변수(출력 변수) 간의 선형 관계, 변수 간의 변화 비율
#**딥러닝에서도 기울기(가중치)**와 **절편(편향)**은 중요한 역할을 하며, 가중치는 입력과 출력 간의 관계를 학습하고, 편향은 출력 값을 조정하는 역할을 함

#13.	교차검증, K-fold 교차검증의 의미와 차이
#교차= 모델이 훈련 데이터와 테스트 데이터에 대해 다양한 분할을 통해 성능을 평가

#K-fold= 데이터를 K개의 균등한 부분으로 나누고 각각의 부분을 테스트 데이터로, 나머지 K-1개 부분을 훈련 데이터로 사용하여 모델을 여러 번 평가

#차이- 데이터셋을 여러 번 분할하여 모델을 평가하므로 교차검증이 더 넓은 개념



#14.	하이퍼파라미터 튜닝이란 무엇인가?
#머신러닝 모델의 성능을 최적화하기 이해 모델 학습 전에 설정해야 하는 파라미터(하이퍼파라미터)를 조정하는 과정, 모델의 구조와 학습 과정에 영향을 미침

#15.	결정트리에서 불순도(Impurity) – 지니 계수(Gini Index)란 무엇인가?
#불순도= 각 클래스의 데이터가 얼마나 섞여 있는지를 측정하는 값, 데이터가 섞여 있다면 그 노드는 불순도가 높음
#지니 계수= 불순도 계산을 위한 지표 중 하나, 불순도를 0과 1 사이의 값으로 나타냄

#16.	앙상블이란 무엇인가?
#여러 개의 모델을 결합하여 더 나은 성능을 얻기 위한 머신러닝 기법, 더 높은 정확도나 더 나은 일반화 성능을 목표

#17.	부트 스트랩핑(bootstraping)이란 무엇인가?
#주어진 데이터셋에서 반복적으로 샘플을 뽑아 통계적 추정을 수행, 확률적 샘플링을 사용하여 복원 추출을 통해 여러 번의 샘플을 생성하고 이를 통해 모델을 훈련시키고 성능을 평가

#18.	배깅(Bagging)이란 무엇인가?
#여러 개의 약한 학습기를 결합하여 예측 성능을 향상시킴. 부트스트래핑 기법을 기반으로 함. 주로 과적합을 줄이고 모델의 안정성을 높임

#19.	주성분 분석(PCA) 이란 무엇인가?
#차원 축소 기법 중 하나, 고차원 데이터에서 정보 손실을 최소화하면서 데이터의 차원을 축소
#선형변환(벡터 공간에서 벡터를 다른 벡터로 변환하는 연산)을 통해 데이터를 새로운 기준 축으로 표현, 첫번째 주성분은 가장 많은 분산을 설명, 남은 주성분이 남은 분산을 설명
