# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split


df = pd.read_csv("C:\\Users\\LG\\Downloads\\titanic.csv", index_col=0)
df

df.columns

# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="Survived")
plt.xlabel("Survived or Not")
plt.ylabel("Count")
plt.title("Survived")

# 레이블 갯수 확인 (숫자)
df['Survived'].value_counts()

# 결측치 확인
df.isnull().sum()

# 결측치 제거
df = df.dropna()
df.isnull().sum()

# 컬럼별 히스토그램 확인
# 첫 번째 그래프: Age 분포
ax1 = plt.subplot(1,2,1)
sns.histplot(df['Age'], kde=True, bins=30, ax=ax1)
ax1.set_title("Distribution of Age")

# 두 번째 그래프: Fare 분포
ax2 = plt.subplot(1,2,2)
sns.histplot(df['Fare'], kde=True, bins=30, ax=ax2)
ax2.set_title("Distribution of Fare")

# 그래프 표시
plt.show()

# 산점도 확인

import matplotlib.pyplot as plt
import numpy as np

plt.scatter(df['Fare'], df['Age'])
plt.xlabel('Fare')
plt.ylabel('Age')

plt.show()
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# pairplot를 사용해 각 상관관계 살펴보기

sns.pairplot(df,
             vars=['Fare', 'Age', 'Survived', 'Sex'],
            hue ='Survived')
plt.show()

# 특정 칼럼의 범위 확인 및 outlier 확인

sns.set_theme(style="whitegrid")
sns.boxplot(x="Age", data=df, palette="Set3", hue="Survived")
plt.title("Age")
plt.show()

# 각 컬럼별 히스토 그램 확인

fig = plt.figure(figsize = (15,20))
df.hist(figsize=(15, 20), bins=30, edgecolor="black", grid=False)
plt.show()
