# %% [markdown]
# <a href="https://colab.research.google.com/github/gobeomgyu/deeplearning/blob/main/PPG_Cnn_Lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0. 라이브러리 import & 시드
# =========================
import h5py
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# 1. MATLAB v7.3 (.mat) 데이터 로드
# =========================
mat_path = "/content/drive/MyDrive/Colab Notebooks/p096530.mat"  # <- 경로 확인

f = h5py.File(mat_path, "r")
subj = f["Subj_Wins"]
refs = f["#refs#"]

def read_cell(obj, idx):
    """MATLAB cell → numpy array"""
    ref = obj[0, idx]
    return np.array(refs[ref])

print("Subj_Wins keys:", list(subj.keys()))
# Out:
# Subj_Wins keys: ['ABP_F', 'ABP_Lag', 'ABP_Raw', 'ABP_SPeaks', 'ABP_Turns', 'Age', 'CaseID', 'ECG_F', 'ECG_RPeaks', 'ECG_Raw', 'ECG_Record', 'ECG_Record_F', 'Gender', 'IncludeFlag', 'PPG_ABP_Corr', 'PPG_F', 'PPG_Raw', 'PPG_Record', 'PPG_Record_F', 'PPG_SPeaks', 'PPG_Turns', 'SegDBP', 'SegSBP', 'SegmentID', 'SubjectID', 'T', 'WinID', 'WinSeqID']

# %%
# 2. PPG, SBP, DBP, 시간 정보 추출
# =========================
N_total = subj["PPG_F"].shape[1]   # ex) 2200 세그먼트
print("총 세그먼트 수 (원본):", N_total)

ppg_list = []
sbp_list = []
dbp_list = []
t_list   = []

for i in range(N_total):
    # PPG 세그먼트
    ppg = read_cell(subj["PPG_F"], i).astype(np.float32).reshape(-1)
    ppg_list.append(ppg)

    # SBP / DBP
    sbp = read_cell(subj["SegSBP"], i).astype(np.float32).reshape(-1)[0]
    dbp = read_cell(subj["SegDBP"], i).astype(np.float32).reshape(-1)[0]
    sbp_list.append(sbp)
    dbp_list.append(dbp)

    # 시간
    t  = read_cell(subj["T"], i).astype(np.float64).reshape(-1)[0]
    t_list.append(t)

ppg_arr = np.stack(ppg_list, axis=0)   # (N_total, 1250)
sbp_arr = np.array(sbp_list)
dbp_arr = np.array(dbp_list)
t_arr   = np.array(t_list)

print("PPG shape:", ppg_arr.shape)
print("SBP/DBP shape:", sbp_arr.shape, dbp_arr.shape)
# Out:
# 총 세그먼트 수 (원본): 2200
# PPG shape: (2200, 1250)
# SBP/DBP shape: (2200,) (2200,)

# %%
# 3. 환자 번호 추출
# =========================
subj_id_arr = read_cell(subj["SubjectID"], 0)  # ascii code
patient_id = "".join(chr(int(c)) for c in subj_id_arr.reshape(-1))
print("환자 번호(SubjectID):", patient_id)
# Out:
# 환자 번호(SubjectID): p096530

# %%
# 4. 시간 순서 정렬 → 2000 세그먼트 선택
# =========================
order = np.argsort(t_arr)
ppg_sorted = ppg_arr[order]
sbp_sorted = sbp_arr[order]
dbp_sorted = dbp_arr[order]

max_segments = 2000
if ppg_sorted.shape[0] < max_segments:
    raise ValueError(f"2000 세그먼트 필요, 현재 {ppg_sorted.shape[0]}개")

ppg_sorted = ppg_sorted[:max_segments]
sbp_sorted = sbp_sorted[:max_segments]
dbp_sorted = dbp_sorted[:max_segments]

N = max_segments
L = ppg_sorted.shape[1]
print("최종 사용 세그먼트 수:", N)
print("세그먼트 길이:", L)
# Out:
# 최종 사용 세그먼트 수: 2000
# 세그먼트 길이: 1250

# %%
# 5. SBP/DBP 2000 세그먼트 가시화
# =========================
plt.figure(figsize=(12, 4))
plt.plot(sbp_sorted, label="SBP")
plt.plot(dbp_sorted, label="DBP")
plt.title(f"SBP / DBP over 2000 segments (Subject: {patient_id})")
plt.xlabel("Segment index")
plt.ylabel("Blood Pressure (mmHg)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 6. 입력/타깃 텐서 (PPG only)
# =========================
X_all = ppg_sorted[..., np.newaxis]                    # (2000, 1250, 1)
y_all = np.stack([sbp_sorted, dbp_sorted], axis=1)     # (2000, 2)


print("X_all shape:", X_all.shape)
print("y_all shape:", y_all.shape)
# Out:
# X_all shape: (2000, 1250, 1)
# y_all shape: (2000, 2)

# %%
# 7. CNN + BiLSTM 모델 정의
#    (PPG only, SBP/DBP 동시 회귀)
# =========================
def build_ppg_cnn_bilstm_sbp(input_shape):
    """
    PPG only -> SBP 1차원 예측 (개선된 CNN + BiLSTM)
    """
    inp = layers.Input(shape=input_shape)

    # --- CNN 블록 1: 더 큰 receptive field + 강한 풀링 ---
    x = layers.Conv1D(32, 11, padding="same")(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling1D(4)(x)   # 1250 -> ~312

    # --- CNN 블록 2 ---
    x = layers.Conv1D(64, 7, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling1D(2)(x)   # ~312 -> ~156

    # --- CNN 블록 3: 짧은 커널로 미세 패턴 ---
    x = layers.Conv1D(128, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    # --- BiLSTM 두 층으로 깊게 ---
    x = layers.Bidirectional(
        layers.LSTM(64, return_sequences=True)
    )(x)
    x = layers.Bidirectional(
        layers.LSTM(32, return_sequences=False)
    )(x)

    # --- Dense ---
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.3)(x)   # 0.4 → 0.3 (조금 덜 공격적으로)

    out = layers.Dense(1, activation="linear")(x)  # SBP or DBP 하나

    model = models.Model(inputs=inp, outputs=out)

    # lr를 조금 낮추고, MAE로 직접 최적화
    opt = tf.keras.optimizers.Adam(learning_rate=1e-4)

    model.compile(
        optimizer=opt,
        loss="mae",          # SBP/DBP 한 개만 예측할 때는 MAE 괜찮음
        metrics=["mae"]      # 학습 로그에서 바로 MAE 확인용
    )
    return model

# %%
# 8. 5-fold 시간 연속 교차검증 설정
# =========================
fold_size = 320 + 40 + 40  # 400
num_folds = 5

if N < fold_size * num_folds:
    raise ValueError(f"세그먼트 수 부족: 필요 {fold_size * num_folds}, 현재 {N}")

print("총 세그먼트:", N)
print("fold_size:", fold_size, "num_folds:", num_folds)
# Out:
# 총 세그먼트: 2000
# fold_size: 400 num_folds: 5

# %%
# 9. Cross-validation 함수
#   - 입력/타깃 둘 다 train 기준 표준화
#   - MAE/RMSE는 역변환 후 mmHg로 계산
# =========================
def run_time_series_cv_ppg_cnn_bilstm(X_all, y_all):
    mae_sbp_list = []
    mae_dbp_list = []
    rmse_sbp_list = []
    rmse_dbp_list = []

    for fold in range(num_folds):
        start = fold * fold_size
        end   = start + fold_size
        fold_indices = np.arange(start, end)

        train_idx = fold_indices[:320]
        val_idx   = fold_indices[320:360]
        test_idx  = fold_indices[360:400]

        X_train = X_all[train_idx]
        y_train = y_all[train_idx]
        X_val   = X_all[val_idx]
        y_val   = y_all[val_idx]
        X_test  = X_all[test_idx]
        y_test  = y_all[test_idx]

        # ---------- 입력 스케일링 ----------
        N_tr, L_, C_ = X_train.shape
        x_scaler = StandardScaler()

        X_train_flat = X_train.reshape(N_tr, -1)
        X_train_scaled = x_scaler.fit_transform(X_train_flat).reshape(N_tr, L_, C_)

        N_val = X_val.shape[0]
        X_val_scaled = x_scaler.transform(X_val.reshape(N_val, -1)).reshape(N_val, L_, C_)

        N_te = X_test.shape[0]
        X_test_scaled = x_scaler.transform(X_test.reshape(N_te, -1)).reshape(N_te, L_, C_)

        # ---------- 타깃(SBP/DBP) 스케일링 ----------
        y_scaler = StandardScaler()
        y_train_scaled = y_scaler.fit_transform(y_train)
        y_val_scaled   = y_scaler.transform(y_val)
        y_test_scaled  = y_scaler.transform(y_test)  # 손실 계산엔 안 쓰지만 형태 맞춰둠

        # ---------- 모델 생성 & 학습 ----------
        model = build_ppg_cnn_bilstm((L_, C_))

        es = callbacks.EarlyStopping(
            monitor="val_loss",
            patience=20,
            restore_best_weights=True
        )

        rlrop = callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=6,
            verbose=1,
            min_lr=3e-4
        )

        print(f"\n[PPG_CNN+BiLSTM] Fold {fold+1} / {num_folds} 학습 시작")
        history = model.fit(
            X_train_scaled, y_train_scaled,
            validation_data=(X_val_scaled, y_val_scaled),
            epochs=200,
            batch_size=8,
            verbose=1,
            callbacks=[es, rlrop]
        )

        # ---------- 테스트 평가 ----------
        y_pred_scaled = model.predict(X_test_scaled)
        # 표준화 해제 (mmHg 단위로 복원)
        y_pred = y_scaler.inverse_transform(y_pred_scaled)

        mae_sbp = mean_absolute_error(y_test[:, 0], y_pred[:, 0])
        mae_dbp = mean_absolute_error(y_test[:, 1], y_pred[:, 1])

        rmse_sbp = np.sqrt(mean_squared_error(y_test[:, 0], y_pred[:, 0]))
        rmse_dbp = np.sqrt(mean_squared_error(y_test[:, 1], y_pred[:, 1]))

        mae_sbp_list.append(mae_sbp)
        mae_dbp_list.append(mae_dbp)
        rmse_sbp_list.append(rmse_sbp)
        rmse_dbp_list.append(rmse_dbp)

        print(f"[PPG_CNN+BiLSTM] Fold {fold+1} 결과:")
        print(f"  MAE  SBP: {mae_sbp:.3f}, DBP: {mae_dbp:.3f}")
        print(f"  RMSE SBP: {rmse_sbp:.3f}, DBP: {rmse_dbp:.3f}")

    # ---------- 5-fold 평균 & 표준편차 ----------
    mae_sbp_mean = np.mean(mae_sbp_list)
    mae_sbp_std  = np.std(mae_sbp_list)
    mae_dbp_mean = np.mean(mae_dbp_list)
    mae_dbp_std  = np.std(mae_dbp_list)

    rmse_sbp_mean = np.mean(rmse_sbp_list)
    rmse_sbp_std  = np.std(rmse_sbp_list)
    rmse_dbp_mean = np.mean(rmse_dbp_list)
    rmse_dbp_std  = np.std(rmse_dbp_list)

    print("\n====================================")
    print("PPG only CNN+BiLSTM 5-fold 최종 요약")
    print("----- MAE -----")
    print(f" SBP: 평균 {mae_sbp_mean:.3f}, 표준편차 {mae_sbp_std:.3f}")
    print(f" DBP: 평균 {mae_dbp_mean:.3f}, 표준편차 {mae_dbp_std:.3f}")
    print("----- RMSE -----")
    print(f" SBP: 평균 {rmse_sbp_mean:.3f}, 표준편차 {rmse_sbp_std:.3f}")
    print(f" DBP: 평균 {rmse_dbp_mean:.3f}, 표준편차 {rmse_dbp_std:.3f}")
    print("====================================")



    return {
        "mae_sbp_list": mae_sbp_list,
        "mae_dbp_list": mae_dbp_list,
        "rmse_sbp_list": rmse_sbp_list,
        "rmse_dbp_list": rmse_dbp_list,
        "mae_sbp_mean": mae_sbp_mean,
        "mae_sbp_std": mae_sbp_std,
        "mae_dbp_mean": mae_dbp_mean,
        "mae_dbp_std": mae_dbp_std,
        "rmse_sbp_mean": rmse_sbp_mean,
        "rmse_sbp_std": rmse_sbp_std,
        "rmse_dbp_mean": rmse_dbp_mean,
        "rmse_dbp_std": rmse_dbp_std,
    }

# %%
# 10. 5-fold 실행
# =========================
results_ppg_cnn_bilstm = run_time_series_cv_ppg_cnn_bilstm(
    X_all=X_all,
    y_all=y_all
)
# Out:
# [PPG_CNN+BiLSTM] Fold 1 / 5 학습 시작
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 5.4966 - val_loss: 14.0247 - learning_rate: 0.0010
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.0059 - val_loss: 13.6123 - learning_rate: 0.0010
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.8873 - val_loss: 13.6627 - learning_rate: 0.0010
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.7926 - val_loss: 13.7054 - learning_rate: 0.0010
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.7616 - val_loss: 11.8248 - learning_rate: 0.0010
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.6824 - val_loss: 12.9016 - learning_rate: 0.0010
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.6724 - val_loss: 11.0946 - learning_rate: 0.0010
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3921 - val_loss: 11.4363 - learning_rate: 0.0010
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3264 - val_loss: 10.2878 - learning_rate: 0.0010
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1195 - val_loss: 12.1047 - learning_rate: 0.0010
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2327 - val_loss: 12.1636 - learning_rate: 0.0010
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0541 - val_loss: 11.6877 - learning_rate: 0.0010
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8005 - val_loss: 11.4831 - learning_rate: 0.0010
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.8603 - val_loss: 11.2595 - learning_rate: 0.0010
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7926
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.7936 - val_loss: 12.8601 - learning_rate: 0.0010
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.7715 - val_loss: 10.7568 - learning_rate: 5.0000e-04
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2626 - val_loss: 10.7255 - learning_rate: 5.0000e-04
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.5136 - val_loss: 10.7397 - learning_rate: 5.0000e-04
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.2959 - val_loss: 10.6626 - learning_rate: 5.0000e-04
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.3492 - val_loss: 10.4279 - learning_rate: 5.0000e-04
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.2271 - val_loss: 10.2350 - learning_rate: 5.0000e-04
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.2756 - val_loss: 10.3653 - learning_rate: 5.0000e-04
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1986 - val_loss: 10.0686 - learning_rate: 5.0000e-04
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.1799 - val_loss: 10.3101 - learning_rate: 5.0000e-04
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.0853 - val_loss: 10.3910 - learning_rate: 5.0000e-04
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.0080 - val_loss: 10.1488 - learning_rate: 5.0000e-04
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2508 - val_loss: 10.0011 - learning_rate: 5.0000e-04
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.8823 - val_loss: 9.7247 - learning_rate: 5.0000e-04
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1958 - val_loss: 9.2423 - learning_rate: 5.0000e-04
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.9583 - val_loss: 10.0832 - learning_rate: 5.0000e-04
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.8538 - val_loss: 11.1342 - learning_rate: 5.0000e-04
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.9859 - val_loss: 10.6913 - learning_rate: 5.0000e-04
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.8943 - val_loss: 9.7262 - learning_rate: 5.0000e-04
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.6374 - val_loss: 10.1284 - learning_rate: 5.0000e-04
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7320
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0003.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7306 - val_loss: 10.0621 - learning_rate: 5.0000e-04
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.6269 - val_loss: 10.6288 - learning_rate: 3.0000e-04
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5055 - val_loss: 9.8200 - learning_rate: 3.0000e-04
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.6286 - val_loss: 9.9936 - learning_rate: 3.0000e-04
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.4322 - val_loss: 9.9681 - learning_rate: 3.0000e-04
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.4284 - val_loss: 10.2733 - learning_rate: 3.0000e-04
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.5231 - val_loss: 9.5583 - learning_rate: 3.0000e-04
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3237 - val_loss: 8.7932 - learning_rate: 3.0000e-04
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.4150 - val_loss: 8.0341 - learning_rate: 3.0000e-04
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 2.4376 - val_loss: 8.6844 - learning_rate: 3.0000e-04
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 2.2588 - val_loss: 8.8578 - learning_rate: 3.0000e-04
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2700 - val_loss: 8.7483 - learning_rate: 3.0000e-04
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2051 - val_loss: 8.9901 - learning_rate: 3.0000e-04
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0779 - val_loss: 8.6033 - learning_rate: 3.0000e-04
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2036 - val_loss: 8.9535 - learning_rate: 3.0000e-04
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0777 - val_loss: 8.2337 - learning_rate: 3.0000e-04
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.9837 - val_loss: 8.0449 - learning_rate: 3.0000e-04
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.0921 - val_loss: 8.3477 - learning_rate: 3.0000e-04
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.0205 - val_loss: 8.8073 - learning_rate: 3.0000e-04
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.0143 - val_loss: 8.4614 - learning_rate: 3.0000e-04
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.8463 - val_loss: 8.7424 - learning_rate: 3.0000e-04
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9058 - val_loss: 7.8245 - learning_rate: 3.0000e-04
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.9275 - val_loss: 8.2036 - learning_rate: 3.0000e-04
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1801 - val_loss: 8.7034 - learning_rate: 3.0000e-04
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.0216 - val_loss: 8.7419 - learning_rate: 3.0000e-04
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.9531 - val_loss: 8.0566 - learning_rate: 3.0000e-04
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9574 - val_loss: 8.0939 - learning_rate: 3.0000e-04
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8072 - val_loss: 8.1966 - learning_rate: 3.0000e-04
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8631 - val_loss: 6.8904 - learning_rate: 3.0000e-04
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.0722 - val_loss: 6.8161 - learning_rate: 3.0000e-04
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.4453 - val_loss: 9.3480 - learning_rate: 3.0000e-04
# Epoch 66/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1052 - val_loss: 11.3514 - learning_rate: 3.0000e-04
# Epoch 67/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 1.8672 - val_loss: 10.8003 - learning_rate: 3.0000e-04
# Epoch 68/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.7019 - val_loss: 9.8251 - learning_rate: 3.0000e-04
# Epoch 69/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.7178 - val_loss: 9.8108 - learning_rate: 3.0000e-04
# Epoch 70/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7078 - val_loss: 10.3530 - learning_rate: 3.0000e-04
# Epoch 71/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.7696 - val_loss: 10.3151 - learning_rate: 3.0000e-04
# Epoch 72/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.7054 - val_loss: 9.9407 - learning_rate: 3.0000e-04
# Epoch 73/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7130 - val_loss: 8.5010 - learning_rate: 3.0000e-04
# Epoch 74/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6275 - val_loss: 7.9841 - learning_rate: 3.0000e-04
# Epoch 75/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4193 - val_loss: 7.6375 - learning_rate: 3.0000e-04
# Epoch 76/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4660 - val_loss: 8.1709 - learning_rate: 3.0000e-04
# Epoch 77/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6434 - val_loss: 7.8087 - learning_rate: 3.0000e-04
# Epoch 78/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.6912 - val_loss: 9.5926 - learning_rate: 3.0000e-04
# Epoch 79/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1.9181 - val_loss: 10.3543 - learning_rate: 3.0000e-04
# Epoch 80/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1.6957 - val_loss: 13.2572 - learning_rate: 3.0000e-04
# Epoch 81/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5408 - val_loss: 9.6552 - learning_rate: 3.0000e-04
# Epoch 82/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6251 - val_loss: 7.6957 - learning_rate: 3.0000e-04
# Epoch 83/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.3885 - val_loss: 8.3542 - learning_rate: 3.0000e-04
# Epoch 84/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4283 - val_loss: 8.0228 - learning_rate: 3.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step
# [PPG_CNN+BiLSTM] Fold 1 결과:
#   MAE  SBP: 10.392, DBP: 2.764
#   RMSE SBP: 11.159, DBP: 3.175
#
# [PPG_CNN+BiLSTM] Fold 2 / 5 학습 시작
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 6.0923 - val_loss: 23.9285 - learning_rate: 0.0010
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.6109 - val_loss: 28.6808 - learning_rate: 0.0010
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.1288 - val_loss: 31.8080 - learning_rate: 0.0010
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.9592 - val_loss: 39.2367 - learning_rate: 0.0010
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.7853 - val_loss: 46.8177 - learning_rate: 0.0010
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.0463 - val_loss: 51.7514 - learning_rate: 0.0010
# Epoch 7/200
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.4552
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.4468 - val_loss: 66.1414 - learning_rate: 0.0010
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2994 - val_loss: 59.6508 - learning_rate: 5.0000e-04
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.3883 - val_loss: 50.9702 - learning_rate: 5.0000e-04
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.0645 - val_loss: 40.9811 - learning_rate: 5.0000e-04
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.1357 - val_loss: 34.1062 - learning_rate: 5.0000e-04
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.9716 - val_loss: 23.4929 - learning_rate: 5.0000e-04
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.0536 - val_loss: 22.1693 - learning_rate: 5.0000e-04
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.6863 - val_loss: 22.1804 - learning_rate: 5.0000e-04
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.8136 - val_loss: 21.5556 - learning_rate: 5.0000e-04
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.6529 - val_loss: 21.6590 - learning_rate: 5.0000e-04
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.8340 - val_loss: 20.8604 - learning_rate: 5.0000e-04
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6317 - val_loss: 20.2797 - learning_rate: 5.0000e-04
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.7384 - val_loss: 21.2488 - learning_rate: 5.0000e-04
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.7430 - val_loss: 21.4445 - learning_rate: 5.0000e-04
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.5117 - val_loss: 20.3533 - learning_rate: 5.0000e-04
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.3934 - val_loss: 21.3347 - learning_rate: 5.0000e-04
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.5370 - val_loss: 20.9848 - learning_rate: 5.0000e-04
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.4046
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0003.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.4065 - val_loss: 20.4503 - learning_rate: 5.0000e-04
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.2674 - val_loss: 20.0940 - learning_rate: 3.0000e-04
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 3.4568 - val_loss: 20.4377 - learning_rate: 3.0000e-04
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.1521 - val_loss: 20.0786 - learning_rate: 3.0000e-04
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.1715 - val_loss: 20.1848 - learning_rate: 3.0000e-04
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.3482 - val_loss: 20.0424 - learning_rate: 3.0000e-04
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.9904 - val_loss: 19.4002 - learning_rate: 3.0000e-04
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1502 - val_loss: 20.0808 - learning_rate: 3.0000e-04
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.0435 - val_loss: 18.7894 - learning_rate: 3.0000e-04
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.0074 - val_loss: 20.1496 - learning_rate: 3.0000e-04
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.8162 - val_loss: 19.8823 - learning_rate: 3.0000e-04
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.9595 - val_loss: 19.2321 - learning_rate: 3.0000e-04
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.9277 - val_loss: 18.5997 - learning_rate: 3.0000e-04
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.7062 - val_loss: 19.2815 - learning_rate: 3.0000e-04
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.1336 - val_loss: 20.6490 - learning_rate: 3.0000e-04
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5416 - val_loss: 21.7680 - learning_rate: 3.0000e-04
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7400 - val_loss: 24.0267 - learning_rate: 3.0000e-04
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.7832 - val_loss: 19.4954 - learning_rate: 3.0000e-04
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.8405 - val_loss: 22.7970 - learning_rate: 3.0000e-04
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.9281 - val_loss: 21.3526 - learning_rate: 3.0000e-04
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3589 - val_loss: 19.6853 - learning_rate: 3.0000e-04
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.5119 - val_loss: 18.2697 - learning_rate: 3.0000e-04
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.4847 - val_loss: 20.1406 - learning_rate: 3.0000e-04
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.3929 - val_loss: 19.1586 - learning_rate: 3.0000e-04
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.4439 - val_loss: 23.6614 - learning_rate: 3.0000e-04
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.4638 - val_loss: 24.8710 - learning_rate: 3.0000e-04
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5724 - val_loss: 26.3940 - learning_rate: 3.0000e-04
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5188 - val_loss: 21.1251 - learning_rate: 3.0000e-04
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.2694 - val_loss: 22.7964 - learning_rate: 3.0000e-04
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.0793 - val_loss: 21.3594 - learning_rate: 3.0000e-04
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1226 - val_loss: 22.1224 - learning_rate: 3.0000e-04
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.3638 - val_loss: 23.1357 - learning_rate: 3.0000e-04
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9970 - val_loss: 23.5169 - learning_rate: 3.0000e-04
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9137 - val_loss: 25.7416 - learning_rate: 3.0000e-04
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.1501 - val_loss: 22.9475 - learning_rate: 3.0000e-04
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.1128 - val_loss: 25.2030 - learning_rate: 3.0000e-04
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.0148 - val_loss: 18.6709 - learning_rate: 3.0000e-04
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.8298 - val_loss: 22.6703 - learning_rate: 3.0000e-04
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.9117 - val_loss: 22.6812 - learning_rate: 3.0000e-04
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0760 - val_loss: 26.3223 - learning_rate: 3.0000e-04
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9063 - val_loss: 20.1225 - learning_rate: 3.0000e-04
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5995 - val_loss: 19.7556 - learning_rate: 3.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step
# [PPG_CNN+BiLSTM] Fold 2 결과:
#   MAE  SBP: 11.665, DBP: 4.707
#   RMSE SBP: 11.864, DBP: 5.032
#
# [PPG_CNN+BiLSTM] Fold 3 / 5 학습 시작
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 6.1274 - val_loss: 12.8525 - learning_rate: 0.0010
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.9251 - val_loss: 15.1056 - learning_rate: 0.0010
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.7415 - val_loss: 17.7082 - learning_rate: 0.0010
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1966 - val_loss: 19.6913 - learning_rate: 0.0010
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.4107 - val_loss: 20.8613 - learning_rate: 0.0010
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.0770 - val_loss: 24.3567 - learning_rate: 0.0010
# Epoch 7/200
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.6894
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6885 - val_loss: 25.6188 - learning_rate: 0.0010
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0086 - val_loss: 26.2583 - learning_rate: 5.0000e-04
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.3396 - val_loss: 28.1376 - learning_rate: 5.0000e-04
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.1551 - val_loss: 31.7166 - learning_rate: 5.0000e-04
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.0299 - val_loss: 31.8701 - learning_rate: 5.0000e-04
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.8524 - val_loss: 30.9784 - learning_rate: 5.0000e-04
# Epoch 13/200
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.9702
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0003.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 2.9598 - val_loss: 33.0614 - learning_rate: 5.0000e-04
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.5813 - val_loss: 31.6620 - learning_rate: 3.0000e-04
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.6208 - val_loss: 31.7319 - learning_rate: 3.0000e-04
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.4214 - val_loss: 31.1969 - learning_rate: 3.0000e-04
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.4360 - val_loss: 30.8328 - learning_rate: 3.0000e-04
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.3366 - val_loss: 31.7979 - learning_rate: 3.0000e-04
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5598 - val_loss: 32.1193 - learning_rate: 3.0000e-04
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 2.1963 - val_loss: 31.3125 - learning_rate: 3.0000e-04
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.4022 - val_loss: 25.0447 - learning_rate: 3.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
# [PPG_CNN+BiLSTM] Fold 3 결과:
#   MAE  SBP: 10.521, DBP: 6.959
#   RMSE SBP: 10.625, DBP: 7.034
#
# [PPG_CNN+BiLSTM] Fold 4 / 5 학습 시작
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 6.2202 - val_loss: 69.6710 - learning_rate: 0.0010
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.4737 - val_loss: 72.3736 - learning_rate: 0.0010
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.4308 - val_loss: 74.0916 - learning_rate: 0.0010
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.2389 - val_loss: 73.6178 - learning_rate: 0.0010
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.0296 - val_loss: 72.8669 - learning_rate: 0.0010
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.0845 - val_loss: 72.1156 - learning_rate: 0.0010
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.7391
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.7312 - val_loss: 70.8233 - learning_rate: 0.0010
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.8113 - val_loss: 71.7237 - learning_rate: 5.0000e-04
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.4983 - val_loss: 70.3532 - learning_rate: 5.0000e-04
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.4418 - val_loss: 68.3900 - learning_rate: 5.0000e-04
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.3715 - val_loss: 67.7001 - learning_rate: 5.0000e-04
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.0908 - val_loss: 67.2560 - learning_rate: 5.0000e-04
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.1225 - val_loss: 62.1654 - learning_rate: 5.0000e-04
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2323 - val_loss: 60.3297 - learning_rate: 5.0000e-04
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.1732 - val_loss: 62.3821 - learning_rate: 5.0000e-04
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.9921 - val_loss: 61.7341 - learning_rate: 5.0000e-04
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.3434 - val_loss: 60.1795 - learning_rate: 5.0000e-04
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.8686 - val_loss: 58.7098 - learning_rate: 5.0000e-04
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.9778 - val_loss: 60.1840 - learning_rate: 5.0000e-04
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.7745 - val_loss: 58.9762 - learning_rate: 5.0000e-04
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8607 - val_loss: 59.8096 - learning_rate: 5.0000e-04
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.8908 - val_loss: 58.4070 - learning_rate: 5.0000e-04
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.9064 - val_loss: 59.3993 - learning_rate: 5.0000e-04
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 3.7877 - val_loss: 57.1278 - learning_rate: 5.0000e-04
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4973 - val_loss: 56.4654 - learning_rate: 5.0000e-04
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.6925 - val_loss: 55.4509 - learning_rate: 5.0000e-04
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2600 - val_loss: 56.4643 - learning_rate: 5.0000e-04
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.4143 - val_loss: 56.6141 - learning_rate: 5.0000e-04
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.7275 - val_loss: 51.9613 - learning_rate: 5.0000e-04
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.7534 - val_loss: 50.3535 - learning_rate: 5.0000e-04
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.6952 - val_loss: 56.7983 - learning_rate: 5.0000e-04
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.5458 - val_loss: 58.1508 - learning_rate: 5.0000e-04
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.4702 - val_loss: 55.8127 - learning_rate: 5.0000e-04
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.1483 - val_loss: 57.0002 - learning_rate: 5.0000e-04
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.2497 - val_loss: 56.9572 - learning_rate: 5.0000e-04
# Epoch 36/200
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.9580
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0003.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.9473 - val_loss: 55.3645 - learning_rate: 5.0000e-04
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2664 - val_loss: 57.9769 - learning_rate: 3.0000e-04
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7768 - val_loss: 58.0478 - learning_rate: 3.0000e-04
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7828 - val_loss: 63.6013 - learning_rate: 3.0000e-04
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.8279 - val_loss: 62.1759 - learning_rate: 3.0000e-04
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.6357 - val_loss: 64.4543 - learning_rate: 3.0000e-04
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.5978 - val_loss: 63.2069 - learning_rate: 3.0000e-04
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.4604 - val_loss: 59.9682 - learning_rate: 3.0000e-04
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.3796 - val_loss: 60.3563 - learning_rate: 3.0000e-04
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.3483 - val_loss: 58.0326 - learning_rate: 3.0000e-04
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.5652 - val_loss: 58.7513 - learning_rate: 3.0000e-04
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5754 - val_loss: 57.0648 - learning_rate: 3.0000e-04
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5346 - val_loss: 59.5886 - learning_rate: 3.0000e-04
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1912 - val_loss: 57.3900 - learning_rate: 3.0000e-04
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.1350 - val_loss: 59.4769 - learning_rate: 3.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step
# [PPG_CNN+BiLSTM] Fold 4 결과:
#   MAE  SBP: 21.362, DBP: 8.200
#   RMSE SBP: 22.169, DBP: 8.673
#
# [PPG_CNN+BiLSTM] Fold 5 / 5 학습 시작
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 5.6985 - val_loss: 7.6356 - learning_rate: 0.0010
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.1088 - val_loss: 6.7528 - learning_rate: 0.0010
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.0379 - val_loss: 6.9571 - learning_rate: 0.0010
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.6185 - val_loss: 7.1930 - learning_rate: 0.0010
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.5669 - val_loss: 7.3811 - learning_rate: 0.0010
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.4955 - val_loss: 7.1320 - learning_rate: 0.0010
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.3930 - val_loss: 7.8662 - learning_rate: 0.0010
# Epoch 8/200
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.4204
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.4413 - val_loss: 7.4409 - learning_rate: 0.0010
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.2280 - val_loss: 6.8890 - learning_rate: 5.0000e-04
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.1456 - val_loss: 7.2594 - learning_rate: 5.0000e-04
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.9156 - val_loss: 7.8150 - learning_rate: 5.0000e-04
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.8476 - val_loss: 7.4068 - learning_rate: 5.0000e-04
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.8747 - val_loss: 7.6438 - learning_rate: 5.0000e-04
# Epoch 14/200
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.5948
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0003.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.6115 - val_loss: 8.3232 - learning_rate: 5.0000e-04
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.8210 - val_loss: 8.1403 - learning_rate: 3.0000e-04
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.5002 - val_loss: 8.9813 - learning_rate: 3.0000e-04
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.4473 - val_loss: 9.4536 - learning_rate: 3.0000e-04
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2633 - val_loss: 9.1207 - learning_rate: 3.0000e-04
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2851 - val_loss: 7.3727 - learning_rate: 3.0000e-04
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2356 - val_loss: 8.4365 - learning_rate: 3.0000e-04
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.9937 - val_loss: 9.3487 - learning_rate: 3.0000e-04
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.9777 - val_loss: 6.8766 - learning_rate: 3.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step
# [PPG_CNN+BiLSTM] Fold 5 결과:
#   MAE  SBP: 15.380, DBP: 3.878
#   RMSE SBP: 16.426, DBP: 4.584
#
# ====================================
# PPG only CNN+BiLSTM 5-fold 최종 요약
# ----- MAE -----
#  SBP: 평균 13.864, 표준편차 4.161
#  DBP: 평균 5.301, 표준편차 1.998
# ----- RMSE -----
#  SBP: 평균 14.449, 표준편차 4.373
#  DBP: 평균 5.699, 표준편차 1.933
# ====================================
