# %% [markdown]
# <a href="https://colab.research.google.com/github/gobeomgyu/deeplearning/blob/main/PPG_ECG_CNN_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0. 라이브러리 & 시드
# =========================
import h5py
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# 1. p096530.mat 로드
# =========================
mat_path = "/content/drive/MyDrive/Colab Notebooks/p096530.mat"

f = h5py.File(mat_path, "r")
subj = f["Subj_Wins"]
refs = f["#refs#"]

def read_cell(obj, idx):
    """MATLAB cell (1xN) -> numpy array"""
    ref = obj[0, idx]
    return np.array(refs[ref])

print("Subj_Wins keys:", list(subj.keys()))
# Out:
# Subj_Wins keys: ['ABP_F', 'ABP_Lag', 'ABP_Raw', 'ABP_SPeaks', 'ABP_Turns', 'Age', 'CaseID', 'ECG_F', 'ECG_RPeaks', 'ECG_Raw', 'ECG_Record', 'ECG_Record_F', 'Gender', 'IncludeFlag', 'PPG_ABP_Corr', 'PPG_F', 'PPG_Raw', 'PPG_Record', 'PPG_Record_F', 'PPG_SPeaks', 'PPG_Turns', 'SegDBP', 'SegSBP', 'SegmentID', 'SubjectID', 'T', 'WinID', 'WinSeqID']

# %%
# 2. PPG, ECG, SBP, DBP, 시간 추출
# =========================
N_total = subj["PPG_F"].shape[1]  # (1, 2200) -> 세그먼트 개수
print("총 세그먼트 수 (원본):", N_total)

ppg_list = []
ecg_list = []
sbp_list = []
dbp_list = []
t_list   = []

for i in range(N_total):
    # PPG / ECG 세그먼트: (1, 1250) -> (1250,)
    ppg = read_cell(subj["PPG_F"], i).astype(np.float32).reshape(-1)
    ecg = read_cell(subj["ECG_F"], i).astype(np.float32).reshape(-1)
    ppg_list.append(ppg)
    ecg_list.append(ecg)

    # SBP / DBP: (1,1) -> scalar
    sbp = read_cell(subj["SegSBP"], i).astype(np.float32)[0, 0]
    dbp = read_cell(subj["SegDBP"], i).astype(np.float32)[0, 0]
    sbp_list.append(sbp)
    dbp_list.append(dbp)

    # 시간 T: (1,1250) 중 첫 번째 값만 사용해서 정렬
    T  = read_cell(subj["T"], i).astype(np.float64)
    t_list.append(float(T[0, 0]))

ppg_arr = np.stack(ppg_list, axis=0)   # (2200, 1250)
ecg_arr = np.stack(ecg_list, axis=0)   # (2200, 1250)
sbp_arr = np.array(sbp_list)           # (2200,)
dbp_arr = np.array(dbp_list)
t_arr   = np.array(t_list)

print("PPG shape:", ppg_arr.shape)
print("ECG shape:", ecg_arr.shape)
print("SBP/DBP shape:", sbp_arr.shape, dbp_arr.shape)
# Out:
# 총 세그먼트 수 (원본): 2200
# PPG shape: (2200, 1250)
# ECG shape: (2200, 1250)
# SBP/DBP shape: (2200,) (2200,)

# %%
# 3. 환자 번호(SubjectID) 출력
# =========================
subj_id_arr = read_cell(subj["SubjectID"], 0)  # ASCII 코드
patient_id = "".join(chr(int(c)) for c in subj_id_arr.reshape(-1))
print("환자 번호(SubjectID):", patient_id)
# Out:
# 환자 번호(SubjectID): p096530

# %%
# 4. 시간순 정렬 후 앞 2000 세그먼트만 사용
# =========================
order = np.argsort(t_arr)  # 시간 기준 오름차순 인덱스
ppg_sorted = ppg_arr[order]
ecg_sorted = ecg_arr[order]
sbp_sorted = sbp_arr[order]
dbp_sorted = dbp_arr[order]

max_segments = 2000
if ppg_sorted.shape[0] < max_segments:
    raise ValueError(f"2000 세그먼트 필요, 현재 {ppg_sorted.shape[0]}개입니다.")

ppg_sorted = ppg_sorted[:max_segments]
ecg_sorted = ecg_sorted[:max_segments]
sbp_sorted = sbp_sorted[:max_segments]
dbp_sorted = dbp_sorted[:max_segments]

N = max_segments
L = ppg_sorted.shape[1]
print("최종 사용 세그먼트 수:", N)
print("세그먼트 길이:", L)
# Out:
# 최종 사용 세그먼트 수: 2000
# 세그먼트 길이: 1250

# %%
# 5. SBP/DBP 전체 구간 그래프
# =========================
plt.figure(figsize=(12, 4))
plt.plot(sbp_sorted, label="SBP")
plt.plot(dbp_sorted, label="DBP")
plt.title(f"SBP / DBP over 2000 segments (Subject: {patient_id})")
plt.xlabel("Segment index (0~1999)")
plt.ylabel("Blood Pressure (mmHg)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 6. 입력/타깃 텐서 (PPG+ECG)
#    X: (N, L, 2)   [PPG, ECG]
#    y: (N, 2)      [SBP, DBP]
# =========================
X_all = np.stack([ppg_sorted, ecg_sorted], axis=-1)   # (2000, 1250, 2)
y_all = np.stack([sbp_sorted, dbp_sorted], axis=1)    # (2000, 2)

print("X_all shape:", X_all.shape)
print("y_all shape:", y_all.shape)
# Out:
# X_all shape: (2000, 1250, 2)
# y_all shape: (2000, 2)

# %%
# 7. PPG+ECG CNN+LSTM 모델 정의
# =========================
def build_ppg_ecg_cnn_lstm(input_shape):
    """
    PPG + ECG 2채널 입력 -> [SBP, DBP] 회귀
    CNN + LSTM 모델
    input_shape: (L, 2)
    """
    inp = layers.Input(shape=input_shape)

    # --- CNN feature extractor ---
    x = layers.Conv1D(32, kernel_size=7, padding="same", activation="relu")(inp)
    x = layers.MaxPooling1D(2)(x)

    x = layers.Conv1D(64, kernel_size=5, padding="same", activation="relu")(x)
    x = layers.MaxPooling1D(2)(x)

    x = layers.Conv1D(64, kernel_size=3, padding="same", activation="relu")(x)

    # --- LSTM ---
    x = layers.LSTM(64, return_sequences=False)(x)

    # --- Dense ---
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    out = layers.Dense(2, activation="linear")(x)   # [SBP, DBP]

    model = models.Model(inputs=inp, outputs=out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="mse"  # 회귀, SBP/DBP 동시에
    )
    return model

# %%
# 8. 5-fold 시간 연속 교차검증 설정
# =========================
fold_size = 320 + 40 + 40  # = 400
num_folds = 5

if N < fold_size * num_folds:
    raise ValueError(f"세그먼트 수 부족: 필요 {fold_size * num_folds}, 현재 {N}")

print("총 세그먼트:", N)
print("fold_size:", fold_size, "num_folds:", num_folds)
# Out:
# 총 세그먼트: 2000
# fold_size: 400 num_folds: 5

# %%
# 9. 5-fold CV 실행 함수
#    - 각 fold: 320 train, 40 val, 40 test (시간 순서 유지)
#    - 입력 X만 StandardScaler로 스케일링
#    - SBP/DBP 각각 MAE, RMSE 계산
# =========================
def run_time_series_cv_ppg_ecg(X_all, y_all):
    mae_sbp_list = []
    mae_dbp_list = []
    rmse_sbp_list = []
    rmse_dbp_list = []

    for fold in range(num_folds):
        start = fold * fold_size
        end   = start + fold_size
        fold_idx = np.arange(start, end)

        train_idx = fold_idx[:320]
        val_idx   = fold_idx[320:360]
        test_idx  = fold_idx[360:400]

        X_train = X_all[train_idx]
        y_train = y_all[train_idx]
        X_val   = X_all[val_idx]
        y_val   = y_all[val_idx]
        X_test  = X_all[test_idx]
        y_test  = y_all[test_idx]

        # ------- 입력 스케일링 -------
        N_tr, L_, C_ = X_train.shape
        scaler = StandardScaler()

        X_train_flat = X_train.reshape(N_tr, -1)
        X_train_scaled = scaler.fit_transform(X_train_flat).reshape(N_tr, L_, C_)

        N_val = X_val.shape[0]
        X_val_scaled = scaler.transform(X_val.reshape(N_val, -1)).reshape(N_val, L_, C_)

        N_te = X_test.shape[0]
        X_test_scaled = scaler.transform(X_test.reshape(N_te, -1)).reshape(N_te, L_, C_)

        # ------- 모델 생성 & 학습 -------
        model = build_ppg_ecg_cnn_lstm((L_, C_))

        es = callbacks.EarlyStopping(
            monitor="val_loss",
            patience=10,
            restore_best_weights=True
        )

        print(f"\n[PPG+ECG CNN+LSTM] Fold {fold+1}/{num_folds} 학습 시작")
        history = model.fit(
            X_train_scaled, y_train,
            validation_data=(X_val_scaled, y_val),
            epochs=80,
            batch_size=16,
            verbose=1,
            callbacks=[es]
        )

        # ------- 테스트 평가 -------
        y_pred = model.predict(X_test_scaled)

        mae_sbp = mean_absolute_error(y_test[:, 0], y_pred[:, 0])
        mae_dbp = mean_absolute_error(y_test[:, 1], y_pred[:, 1])

        rmse_sbp = np.sqrt(mean_squared_error(y_test[:, 0], y_pred[:, 0]))
        rmse_dbp = np.sqrt(mean_squared_error(y_test[:, 1], y_pred[:, 1]))

        mae_sbp_list.append(mae_sbp)
        mae_dbp_list.append(mae_dbp)
        rmse_sbp_list.append(rmse_sbp)
        rmse_dbp_list.append(rmse_dbp)

        print(f"[PPG+ECG CNN+LSTM] Fold {fold+1} 결과:")
        print(f"  MAE  SBP: {mae_sbp:.3f}, DBP: {mae_dbp:.3f}")
        print(f"  RMSE SBP: {rmse_sbp:.3f}, DBP: {rmse_dbp:.3f}")

    # ------- 5-fold 평균 & 표준편차 -------
    mae_sbp_mean = np.mean(mae_sbp_list)
    mae_sbp_std  = np.std(mae_sbp_list)
    mae_dbp_mean = np.mean(mae_dbp_list)
    mae_dbp_std  = np.std(mae_dbp_list)

    rmse_sbp_mean = np.mean(rmse_sbp_list)
    rmse_sbp_std  = np.std(rmse_sbp_list)
    rmse_dbp_mean = np.mean(rmse_dbp_list)
    rmse_dbp_std  = np.std(rmse_dbp_list)

    print("\n====================================")
    print("PPG+ECG CNN+LSTM 5-fold 최종 요약")
    print("----- MAE -----")
    print(f" SBP: 평균 {mae_sbp_mean:.3f}, 표준편차 {mae_sbp_std:.3f}")
    print(f" DBP: 평균 {mae_dbp_mean:.3f}, 표준편차 {mae_dbp_std:.3f}")
    print("----- RMSE -----")
    print(f" SBP: 평균 {rmse_sbp_mean:.3f}, 표준편차 {rmse_sbp_std:.3f}")
    print(f" DBP: 평균 {rmse_dbp_mean:.3f}, 표준편차 {rmse_dbp_std:.3f}")
    print("====================================")

    return {
        "mae_sbp_list": mae_sbp_list,
        "mae_dbp_list": mae_dbp_list,
        "rmse_sbp_list": rmse_sbp_list,
        "rmse_dbp_list": rmse_dbp_list,
        "mae_sbp_mean": mae_sbp_mean,
        "mae_sbp_std": mae_sbp_std,
        "mae_dbp_mean": mae_dbp_mean,
        "mae_dbp_std": mae_dbp_std,
        "rmse_sbp_mean": rmse_sbp_mean,
        "rmse_sbp_std": rmse_sbp_std,
        "rmse_dbp_mean": rmse_dbp_mean,
        "rmse_dbp_std": rmse_dbp_std,
    }

# %%
# 10. 5-fold 실행
# =========================
results_ppg_ecg = run_time_series_cv_ppg_ecg(X_all, y_all)
# Out:
# [PPG+ECG CNN+LSTM] Fold 1/5 학습 시작
# Epoch 1/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - loss: 13367.8965 - val_loss: 11350.3154
# Epoch 2/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 12247.1953 - val_loss: 9756.1855
# Epoch 3/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10513.0361 - val_loss: 7993.3916
# Epoch 4/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8626.3164 - val_loss: 6057.0132
# Epoch 5/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6534.8779 - val_loss: 4145.1084
# Epoch 6/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4500.2451 - val_loss: 2491.9658
# Epoch 7/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2873.7136 - val_loss: 1264.9557
# Epoch 8/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1656.5597 - val_loss: 511.6215
# Epoch 9/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 933.0934 - val_loss: 149.3757
# Epoch 10/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 455.1720 - val_loss: 25.3772
# Epoch 11/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 348.3394 - val_loss: 2.1574
# Epoch 12/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 358.6832 - val_loss: 7.9000
# Epoch 13/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 275.6183 - val_loss: 17.7442
# Epoch 14/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 278.5887 - val_loss: 22.0707
# Epoch 15/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 323.6322 - val_loss: 27.0894
# Epoch 16/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 308.7037 - val_loss: 33.0129
# Epoch 17/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 274.7192 - val_loss: 34.6166
# Epoch 18/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 300.1918 - val_loss: 36.2593
# Epoch 19/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 301.6378 - val_loss: 42.9140
# Epoch 20/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 265.4445 - val_loss: 45.1982
# Epoch 21/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 239.1091 - val_loss: 27.9124
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# [PPG+ECG CNN+LSTM] Fold 1 결과:
#   MAE  SBP: 3.317, DBP: 0.539
#   RMSE SBP: 3.575, DBP: 0.750
#
# [PPG+ECG CNN+LSTM] Fold 2/5 학습 시작
# Epoch 1/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 11850.9287 - val_loss: 9178.2637
# Epoch 2/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10291.4648 - val_loss: 7308.7764
# Epoch 3/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8282.8564 - val_loss: 5429.1260
# Epoch 4/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6187.2524 - val_loss: 3530.0317
# Epoch 5/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4086.4456 - val_loss: 1904.3030
# Epoch 6/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2371.4905 - val_loss: 789.0087
# Epoch 7/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1226.1294 - val_loss: 216.5574
# Epoch 8/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 648.9326 - val_loss: 27.9692
# Epoch 9/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 305.3479 - val_loss: 12.5534
# Epoch 10/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 256.6023 - val_loss: 26.0306
# Epoch 11/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 254.6239 - val_loss: 37.6273
# Epoch 12/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 201.6254 - val_loss: 48.0370
# Epoch 13/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 233.0904 - val_loss: 55.3801
# Epoch 14/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 213.6815 - val_loss: 54.0414
# Epoch 15/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 215.5143 - val_loss: 51.2362
# Epoch 16/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 188.8427 - val_loss: 42.3212
# Epoch 17/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 230.7226 - val_loss: 50.4190
# Epoch 18/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 228.3196 - val_loss: 49.5784
# Epoch 19/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 228.0747 - val_loss: 48.0638
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# [PPG+ECG CNN+LSTM] Fold 2 결과:
#   MAE  SBP: 3.894, DBP: 4.207
#   RMSE SBP: 3.955, DBP: 4.252
#
# [PPG+ECG CNN+LSTM] Fold 3/5 학습 시작
# Epoch 1/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9987.9678 - val_loss: 7448.7236
# Epoch 2/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8870.7881 - val_loss: 6049.4790
# Epoch 3/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7249.2334 - val_loss: 4593.1748
# Epoch 4/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5534.3804 - val_loss: 3103.8613
# Epoch 5/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3872.4839 - val_loss: 1779.4750
# Epoch 6/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2463.3938 - val_loss: 805.9805
# Epoch 7/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1350.6379 - val_loss: 252.5374
# Epoch 8/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 702.9576 - val_loss: 39.8796
# Epoch 9/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 373.2964 - val_loss: 9.0154
# Epoch 10/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 373.5457 - val_loss: 32.8323
# Epoch 11/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 230.7242 - val_loss: 52.6857
# Epoch 12/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 249.7729 - val_loss: 57.8394
# Epoch 13/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 229.3448 - val_loss: 62.4271
# Epoch 14/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 244.8320 - val_loss: 58.5977
# Epoch 15/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 268.3676 - val_loss: 49.6489
# Epoch 16/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 242.0612 - val_loss: 52.1152
# Epoch 17/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 255.4732 - val_loss: 64.3354
# Epoch 18/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 263.9910 - val_loss: 60.1748
# Epoch 19/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 240.3307 - val_loss: 59.1291
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79f72428f4c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79f72428f4c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step
# [PPG+ECG CNN+LSTM] Fold 3 결과:
#   MAE  SBP: 1.137, DBP: 3.943
#   RMSE SBP: 1.340, DBP: 4.050
#
# [PPG+ECG CNN+LSTM] Fold 4/5 학습 시작
# Epoch 1/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 8958.7617 - val_loss: 12101.5703
# Epoch 2/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7714.5674 - val_loss: 10235.0225
# Epoch 3/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6289.1792 - val_loss: 8498.8018
# Epoch 4/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4999.3057 - val_loss: 6694.7983
# Epoch 5/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3544.3811 - val_loss: 4949.8242
# Epoch 6/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2389.7532 - val_loss: 3433.5835
# Epoch 7/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1502.1771 - val_loss: 2256.2668
# Epoch 8/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 733.4414 - val_loss: 1469.7812
# Epoch 9/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 436.5591 - val_loss: 995.9172
# Epoch 10/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 355.7058 - val_loss: 736.7861
# Epoch 11/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 288.5196 - val_loss: 620.0985
# Epoch 12/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 231.6534 - val_loss: 592.2234
# Epoch 13/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 285.5417 - val_loss: 585.5895
# Epoch 14/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 256.0038 - val_loss: 585.8793
# Epoch 15/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 209.2334 - val_loss: 600.7214
# Epoch 16/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 244.5649 - val_loss: 611.7261
# Epoch 17/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 245.9924 - val_loss: 597.8108
# Epoch 18/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 241.4895 - val_loss: 609.3180
# Epoch 19/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 229.5832 - val_loss: 569.3867
# Epoch 20/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 222.0633 - val_loss: 573.6048
# Epoch 21/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 273.5526 - val_loss: 564.5427
# Epoch 22/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 247.9498 - val_loss: 574.1645
# Epoch 23/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 255.0716 - val_loss: 589.5680
# Epoch 24/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 215.9607 - val_loss: 608.7745
# Epoch 25/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 241.8078 - val_loss: 586.7062
# Epoch 26/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 230.1285 - val_loss: 576.1008
# Epoch 27/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 226.9588 - val_loss: 569.1920
# Epoch 28/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 191.9686 - val_loss: 611.1423
# Epoch 29/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 211.3301 - val_loss: 592.6791
# Epoch 30/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 210.3809 - val_loss: 598.5015
# Epoch 31/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 235.6818 - val_loss: 586.6561
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# [PPG+ECG CNN+LSTM] Fold 4 결과:
#   MAE  SBP: 23.944, DBP: 10.149
#   RMSE SBP: 24.666, DBP: 10.579
#
# [PPG+ECG CNN+LSTM] Fold 5/5 학습 시작
# Epoch 1/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 15951.1084 - val_loss: 17072.7383
# Epoch 2/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 14386.3926 - val_loss: 14850.2402
# Epoch 3/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12361.8564 - val_loss: 12789.2529
# Epoch 4/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10481.9189 - val_loss: 10563.0508
# Epoch 5/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8304.6299 - val_loss: 8319.2910
# Epoch 6/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6544.9863 - val_loss: 6255.0547
# Epoch 7/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4613.4585 - val_loss: 4505.1909
# Epoch 8/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3362.2881 - val_loss: 3151.1875
# Epoch 9/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2165.5886 - val_loss: 2172.0957
# Epoch 10/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1708.9307 - val_loss: 1482.3933
# Epoch 11/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1198.6476 - val_loss: 1011.4490
# Epoch 12/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 906.2332 - val_loss: 690.2925
# Epoch 13/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 736.1814 - val_loss: 501.9838
# Epoch 14/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 615.9083 - val_loss: 381.5384
# Epoch 15/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 633.9800 - val_loss: 285.5562
# Epoch 16/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 438.5402 - val_loss: 241.3437
# Epoch 17/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 493.7026 - val_loss: 218.0246
# Epoch 18/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 489.6603 - val_loss: 204.2476
# Epoch 19/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 450.9917 - val_loss: 206.0157
# Epoch 20/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 447.8744 - val_loss: 204.2482
# Epoch 21/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 450.2484 - val_loss: 187.1357
# Epoch 22/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 446.3785 - val_loss: 204.3352
# Epoch 23/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 483.1028 - val_loss: 177.7510
# Epoch 24/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 400.6738 - val_loss: 188.8766
# Epoch 25/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 430.8253 - val_loss: 223.3487
# Epoch 26/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 477.7132 - val_loss: 214.2858
# Epoch 27/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 516.3658 - val_loss: 198.3667
# Epoch 28/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 473.6931 - val_loss: 184.5582
# Epoch 29/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 437.5862 - val_loss: 185.7896
# Epoch 30/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 452.0626 - val_loss: 192.6267
# Epoch 31/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 395.3154 - val_loss: 180.6148
# Epoch 32/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 443.0431 - val_loss: 173.7097
# Epoch 33/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 385.6358 - val_loss: 178.4790
# Epoch 34/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 439.5687 - val_loss: 209.8493
# Epoch 35/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 453.3246 - val_loss: 232.2990
# Epoch 36/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 501.4884 - val_loss: 205.0321
# Epoch 37/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 476.3275 - val_loss: 182.5618
# Epoch 38/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 431.5198 - val_loss: 164.0217
# Epoch 39/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 341.9629 - val_loss: 169.9751
# Epoch 40/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 476.7728 - val_loss: 191.9135
# Epoch 41/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 454.6218 - val_loss: 198.6408
# Epoch 42/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 482.4660 - val_loss: 186.9975
# Epoch 43/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 481.0418 - val_loss: 169.2055
# Epoch 44/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 491.6653 - val_loss: 166.2538
# Epoch 45/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 428.7290 - val_loss: 194.8351
# Epoch 46/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 499.3280 - val_loss: 196.3414
# Epoch 47/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 467.1533 - val_loss: 186.7998
# Epoch 48/80
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 440.4508 - val_loss: 173.5365
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# [PPG+ECG CNN+LSTM] Fold 5 결과:
#   MAE  SBP: 16.902, DBP: 4.041
#   RMSE SBP: 17.881, DBP: 4.825
#
# ====================================
# PPG+ECG CNN+LSTM 5-fold 최종 요약
# ----- MAE -----
#  SBP: 평균 9.839, 표준편차 8.971
#  DBP: 평균 4.576, 표준편차 3.104
# ----- RMSE -----
#  SBP: 평균 10.284, 표준편차 9.269
#  DBP: 평균 4.891, 표준편차 3.182
# ====================================
